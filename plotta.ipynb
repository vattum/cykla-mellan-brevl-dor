# %%
x = [7.29, 19.81, 25.29, 42.84, 64.84]
y = [3.86, 6.58, 7.18, 8.55, 12.25]
print(x, y)
# Out:
# [7.29, 19.81, 25.29, 42.84, 64.84] [3.86, 6.58, 7.18, 8.55, 12.25]

# %%
import matplotlib.pyplot as plt
plt.plot(x, y, "*")
plt.xlabel("avstånd i meter")
plt.ylabel("tid i sekunder")
plt.grid()
plt.title("cykla mellan brevlådor")
plt.savefig("resultat-av-mätningar.png")
